# %%
def extract_mc_features(mc_contours, tophat_norm):
    """
    Extract features from microcalcifications (MCs).
    Safely handles empty or single MC cases.
    """
    # Initialize all features with default values
    mc_count = len(mc_contours)
    mc_avg_area = 0.0
    mc_std_area = 0.0
    mc_density = 0.0      # always initialized
    mc_mean_int = 0.0

    if mc_count > 0:
        areas = [cv2.contourArea(c) for c in mc_contours]
        mc_avg_area = float(np.mean(areas))
        mc_std_area = float(np.std(areas))

        # --- cluster density ---
        if mc_count > 1:
            xs, ys = [], []
            for c in mc_contours:
                x, y, w, h = cv2.boundingRect(c)
                xs.extend([x, x + w])
                ys.extend([y, y + h])
            cluster_area = (max(xs) - min(xs)) * (max(ys) - min(ys))
            mc_density = mc_count / (cluster_area + 1e-6)
        else:
            mc_density = 1.0  # assign default for single MC

        # --- average intensity of MCs ---
        mask = np.zeros_like(tophat_norm, dtype=np.uint8)
        for c in mc_contours:
            cv2.drawContours(mask, [c], -1, 255, -1)

        vals = tophat_norm[mask == 255]
        if len(vals) > 0:
            mc_mean_int = float(np.mean(vals))

    # Return feature vector
    mc_feature_vector = [
        mc_count,
        mc_avg_area,
        mc_std_area,
        mc_density,
        mc_mean_int
    ]

    return mc_feature_vector

def build_master_vector(mass_features_df, mc_features_list):
    """
    Combine mass features (DataFrame) with MC features (list)
    into a single flat vector (list or Series)
    """
    # Convert DataFrame row to list
    mass_features_list = mass_features_df.iloc[0].tolist()  # first row
    # Combine
    master_vector = mass_features_list + mc_features_list
    return master_vector

# %%
import pandas as pd
import cv2
import numpy as np

from Feature_Extraction import (
    extract_mass_features)

from input import get_mass_data


# Load original dataset
df = pd.read_csv(
    r"E:\Breast_Cancer_Detection_Imp\test_dataset.csv"
)

all_rows = []
import time

start_total = time.time()

for idx, row in df.iterrows():
    start = time.time()

    img_path = row['PATH']
    label    = row['TYPE']   # or CLASS

    # Load image
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        print(f"Could not read {img_path}")
        continue

    # PREPROCESSING 
    mass_region, clean_mask = get_mass_data(img)

    if mass_region is None or clean_mask is None:
        print(f"No mass detected in {img_path}")
        continue

    # MASS FEATURES
    mass_features = extract_mass_features(
        mass_region_gray=mass_region,
        clean_mask=clean_mask
    )

    # MC PREPROCESSING 
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (9, 9))
    tophat = cv2.morphologyEx(mass_region, cv2.MORPH_TOPHAT, kernel)

    _, mc_bin = cv2.threshold(tophat, 200, 255, cv2.THRESH_BINARY)

    mc_contours, _ = cv2.findContours(
        mc_bin,
        cv2.RETR_EXTERNAL,
        cv2.CHAIN_APPROX_SIMPLE
    )

    # MC FEATURES
    mc_features = extract_mc_features(mc_contours, tophat)

    # MASTER FEATURE VECTOR
    master_vector = build_master_vector(mass_features, mc_features)
    master_vector.append(label)

    all_rows.append(master_vector)

    end = time.time()
    print(f"Row {idx+1} processed in {end-start:.2f} seconds")

print(f"Total time: {time.time()-start_total:.2f} seconds")


# Save final dataset
FEATURE_COLUMNS = [
    'Area','Perimeter','Circularity','Eccentricity','Solidity','Extent',
    'Mean_Intensity','Max_Intensity','Std_Intensity',
    'Contrast','Dissimilarity','Homogeneity','Energy','Correlation','ASM',
    'MC_Count','MC_AvgArea','MC_StdArea','MC_Density','MC_MeanIntensity',
    'Label'
]

final_df = pd.DataFrame(all_rows, columns=FEATURE_COLUMNS)
final_df.to_excel("svm_features_test_dataset.xlsx", index=False)
# Out:
# Row 1 processed in 9.15 seconds
# Row 2 processed in 4.84 seconds
# Row 3 processed in 7.06 seconds
# Row 4 processed in 5.58 seconds
# Row 5 processed in 15.08 seconds
# Row 6 processed in 9.30 seconds
# Row 7 processed in 4.74 seconds
# Row 8 processed in 6.86 seconds
# Row 9 processed in 8.78 seconds
# Row 10 processed in 7.21 seconds
# Row 11 processed in 7.84 seconds
# Row 12 processed in 7.08 seconds
# Row 13 processed in 14.25 seconds
# Row 14 processed in 6.60 seconds
# Row 15 processed in 7.14 seconds
# Row 16 processed in 13.63 seconds
# Row 17 processed in 8.93 seconds
# Row 18 processed in 6.51 seconds
# Row 19 processed in 8.40 seconds
# Row 20 processed in 6.34 seconds
# Row 21 processed in 5.45 seconds
# Row 22 processed in 4.52 seconds
# Row 23 processed in 9.07 seconds
# Row 24 processed in 6.39 seconds
# Row 25 processed in 5.52 seconds
# Row 26 processed in 6.40 seconds
# Row 27 processed in 6.90 seconds
# Row 28 processed in 7.32 seconds
# Row 29 processed in 6.94 seconds
# Row 30 processed in 8.04 seconds
# Row 31 processed in 12.55 seconds
# Row 32 processed in 8.32 seconds
# Row 33 processed in 9.03 seconds
# Row 34 processed in 5.73 seconds
# Row 35 processed in 4.38 seconds
# Row 36 processed in 8.53 seconds
# Row 37 processed in 6.65 seconds
# Row 38 processed in 7.41 seconds
# Row 39 processed in 6.89 seconds
# Row 40 processed in 7.21 seconds
# Row 41 processed in 8.15 seconds
# Row 42 processed in 4.93 seconds
# Row 43 processed in 8.28 seconds
# Row 44 processed in 6.25 seconds
# Row 45 processed in 5.78 seconds
# Row 46 processed in 4.55 seconds
# Total time: 346.53 seconds

# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report

# Load training and test data from separate Excel files
train_data = pd.read_excel(r"E:\Breast_Cancer_Detection_Imp\svm_features_dataset.xlsx")
test_data  = pd.read_excel(r"E:\Breast_Cancer_Detection_Imp\svm_features_test_dataset.xlsx")  # your test file

# Separate features and labels
X_train = train_data.iloc[:, :-1].values
y_train = train_data.iloc[:, -1].values

X_test = test_data.iloc[:, :-1].values
y_test = test_data.iloc[:, -1].values

# Scale features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Train SVM
svm_model = SVC(
    kernel='rbf',
    C=1.0,
    gamma='scale',
    class_weight='balanced',  # automatically balances minority classes
    decision_function_shape='ovr'
)

svm_model.fit(X_train, y_train)

# Predict and evaluate
y_pred = svm_model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
# Accuracy: 0.43478260869565216
#                      precision    recall  f1-score   support
#
#                MASS       0.33      0.58      0.42        12
# MICRO_CALCIFICATION       0.29      0.67      0.40         6
#              NORMAL       0.82      0.32      0.46        28
#
#            accuracy                           0.43        46
#           macro avg       0.48      0.52      0.43        46
#        weighted avg       0.62      0.43      0.44        46

# %%
import os

# Path to your folder containing the .pgm files
folder_path = r"E:\Breast_Cancer_Detection_Imp\Dataset\all-mias"

# Loop through all files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".pgm"):
        # Split the name and extension
        name, ext = os.path.splitext(filename)
        
        # Remove last 2 letters from the name
        new_name = name[:-2] + ext
        
        # Full paths
        old_path = os.path.join(folder_path, filename)
        new_path = os.path.join(folder_path, new_name)
        
        # Rename the file
        os.rename(old_path, new_path)
        print(f"Renamed: {filename} -> {new_name}")

print("All files renamed successfully.")
# Out:
# Renamed: mdb001lm.pgm -> mdb001.pgm
# Renamed: mdb002rl.pgm -> mdb002.pgm
# Renamed: mdb003ll.pgm -> mdb003.pgm
# Renamed: mdb004rl.pgm -> mdb004.pgm
# Renamed: mdb005ll.pgm -> mdb005.pgm
# Renamed: mdb006rl.pgm -> mdb006.pgm
# Renamed: mdb007ll.pgm -> mdb007.pgm
# Renamed: mdb008rl.pgm -> mdb008.pgm
# Renamed: mdb009ll.pgm -> mdb009.pgm
# Renamed: mdb010rm.pgm -> mdb010.pgm
# Renamed: mdb011ll.pgm -> mdb011.pgm
# Renamed: mdb012rl.pgm -> mdb012.pgm
# Renamed: mdb013ll.pgm -> mdb013.pgm
# Renamed: mdb014rl.pgm -> mdb014.pgm
# Renamed: mdb015lm.pgm -> mdb015.pgm
# Renamed: mdb016rm.pgm -> mdb016.pgm
# Renamed: mdb017ls.pgm -> mdb017.pgm
# Renamed: mdb018rs.pgm -> mdb018.pgm
# Renamed: mdb019ll.pgm -> mdb019.pgm
# Renamed: mdb020rl.pgm -> mdb020.pgm
# Renamed: mdb021ll.pgm -> mdb021.pgm
# Renamed: mdb022rm.pgm -> mdb022.pgm
# Renamed: mdb023ll.pgm -> mdb023.pgm
# Renamed: mdb024rl.pgm -> mdb024.pgm
# Renamed: mdb025ll.pgm -> mdb025.pgm
# Renamed: mdb026rl.pgm -> mdb026.pgm
# Renamed: mdb027ll.pgm -> mdb027.pgm
# Renamed: mdb028rl.pgm -> mdb028.pgm
# Renamed: mdb029ll.pgm -> mdb029.pgm
# Renamed: mdb030rm.pgm -> mdb030.pgm
# Renamed: mdb031ll.pgm -> mdb031.pgm
# Renamed: mdb032rl.pgm -> mdb032.pgm
# Renamed: mdb033ls.pgm -> mdb033.pgm
# Renamed: mdb034rs.pgm -> mdb034.pgm
# Renamed: mdb035ls.pgm -> mdb035.pgm
# Renamed: mdb036rs.pgm -> mdb036.pgm
# Renamed: mdb037ls.pgm -> mdb037.pgm
# Renamed: mdb038rs.pgm -> mdb038.pgm
# Renamed: mdb039ls.pgm -> mdb039.pgm
# Renamed: mdb040rs.pgm -> mdb040.pgm
# Renamed: mdb041ll.pgm -> mdb041.pgm
# Renamed: mdb042rl.pgm -> mdb042.pgm
# Renamed: mdb043ls.pgm -> mdb043.pgm
# Renamed: mdb044rs.pgm -> mdb044.pgm
# Renamed: mdb045lm.pgm -> mdb045.pgm
# Renamed: mdb046rm.pgm -> mdb046.pgm
# Renamed: mdb047lm.pgm -> mdb047.pgm
# Renamed: mdb048rm.pgm -> mdb048.pgm
# Renamed: mdb049ll.pgm -> mdb049.pgm
# Renamed: mdb050rl.pgm -> mdb050.pgm
# Renamed: mdb051ll.pgm -> mdb051.pgm
# Renamed: mdb052rm.pgm -> mdb052.pgm
# Renamed: mdb053ls.pgm -> mdb053.pgm
# Renamed: mdb054rs.pgm -> mdb054.pgm
# Renamed: mdb055lm.pgm -> mdb055.pgm
# Renamed: mdb056rm.pgm -> mdb056.pgm
# Renamed: mdb057ll.pgm -> mdb057.pgm
# Renamed: mdb058rl.pgm -> mdb058.pgm
# Renamed: mdb059ls.pgm -> mdb059.pgm
# Renamed: mdb060rs.pgm -> mdb060.pgm
# Renamed: mdb061ls.pgm -> mdb061.pgm
# Renamed: mdb062rs.pgm -> mdb062.pgm
# Renamed: mdb063lm.pgm -> mdb063.pgm
# Renamed: mdb064rm.pgm -> mdb064.pgm
# Renamed: mdb065lm.pgm -> mdb065.pgm
# Renamed: mdb066rm.pgm -> mdb066.pgm
# Renamed: mdb067ll.pgm -> mdb067.pgm
# Renamed: mdb068rl.pgm -> mdb068.pgm
# Renamed: mdb069ll.pgm -> mdb069.pgm
# Renamed: mdb070rl.pgm -> mdb070.pgm
# Renamed: mdb071lm.pgm -> mdb071.pgm
# Renamed: mdb072rm.pgm -> mdb072.pgm
# Renamed: mdb073ls.pgm -> mdb073.pgm
# Renamed: mdb074rs.pgm -> mdb074.pgm
# Renamed: mdb075lm.pgm -> mdb075.pgm
# Renamed: mdb076rm.pgm -> mdb076.pgm
# Renamed: mdb077ll.pgm -> mdb077.pgm
# Renamed: mdb078rl.pgm -> mdb078.pgm
# Renamed: mdb079lm.pgm -> mdb079.pgm
# Renamed: mdb080rm.pgm -> mdb080.pgm
# Renamed: mdb081ll.pgm -> mdb081.pgm
# Renamed: mdb082rl.pgm -> mdb082.pgm
# Renamed: mdb083ll.pgm -> mdb083.pgm
# Renamed: mdb084rl.pgm -> mdb084.pgm
# Renamed: mdb085lm.pgm -> mdb085.pgm
# Renamed: mdb086rm.pgm -> mdb086.pgm
# Renamed: mdb087lm.pgm -> mdb087.pgm
# Renamed: mdb088rm.pgm -> mdb088.pgm
# Renamed: mdb089lm.pgm -> mdb089.pgm
# Renamed: mdb090rm.pgm -> mdb090.pgm
# Renamed: mdb091lm.pgm -> mdb091.pgm
# Renamed: mdb092rm.pgm -> mdb092.pgm
# Renamed: mdb093lm.pgm -> mdb093.pgm
# Renamed: mdb094rm.pgm -> mdb094.pgm
# Renamed: mdb095ll.pgm -> mdb095.pgm
# Renamed: mdb096rl.pgm -> mdb096.pgm
# Renamed: mdb097ll.pgm -> mdb097.pgm
# Renamed: mdb098rl.pgm -> mdb098.pgm
# Renamed: mdb099lm.pgm -> mdb099.pgm
# Renamed: mdb100rm.pgm -> mdb100.pgm
# Renamed: mdb101lm.pgm -> mdb101.pgm
# Renamed: mdb102rm.pgm -> mdb102.pgm
# Renamed: mdb103lm.pgm -> mdb103.pgm
# Renamed: mdb104rm.pgm -> mdb104.pgm
# Renamed: mdb105ll.pgm -> mdb105.pgm
# Renamed: mdb106rl.pgm -> mdb106.pgm
# Renamed: mdb107ll.pgm -> mdb107.pgm
# Renamed: mdb108rl.pgm -> mdb108.pgm
# Renamed: mdb109ll.pgm -> mdb109.pgm
# Renamed: mdb110rl.pgm -> mdb110.pgm
# Renamed: mdb111ll.pgm -> mdb111.pgm
# Renamed: mdb112rl.pgm -> mdb112.pgm
# Renamed: mdb113ls.pgm -> mdb113.pgm
# Renamed: mdb114rs.pgm -> mdb114.pgm
# Renamed: mdb115ll.pgm -> mdb115.pgm
# Renamed: mdb116rl.pgm -> mdb116.pgm
# Renamed: mdb117ll.pgm -> mdb117.pgm
# Renamed: mdb118rl.pgm -> mdb118.pgm
# Renamed: mdb119ll.pgm -> mdb119.pgm
# Renamed: mdb120rl.pgm -> mdb120.pgm
# Renamed: mdb121ll.pgm -> mdb121.pgm
# Renamed: mdb122rl.pgm -> mdb122.pgm
# Renamed: mdb123lm.pgm -> mdb123.pgm
# Renamed: mdb124rm.pgm -> mdb124.pgm
# Renamed: mdb125ll.pgm -> mdb125.pgm
# Renamed: mdb126rl.pgm -> mdb126.pgm
# Renamed: mdb127lm.pgm -> mdb127.pgm
# Renamed: mdb128rm.pgm -> mdb128.pgm
# Renamed: mdb129ll.pgm -> mdb129.pgm
# Renamed: mdb130rl.pgm -> mdb130.pgm
# Renamed: mdb131lx.pgm -> mdb131.pgm
# Renamed: mdb132rx.pgm -> mdb132.pgm
# Renamed: mdb133lx.pgm -> mdb133.pgm
# Renamed: mdb134rx.pgm -> mdb134.pgm
# Renamed: mdb135lx.pgm -> mdb135.pgm
# Renamed: mdb136rx.pgm -> mdb136.pgm
# Renamed: mdb137ll.pgm -> mdb137.pgm
# Renamed: mdb138rl.pgm -> mdb138.pgm
# Renamed: mdb139lx.pgm -> mdb139.pgm
# Renamed: mdb140rx.pgm -> mdb140.pgm
# Renamed: mdb141lx.pgm -> mdb141.pgm
# Renamed: mdb142rx.pgm -> mdb142.pgm
# Renamed: mdb143lx.pgm -> mdb143.pgm
# Renamed: mdb144rx.pgm -> mdb144.pgm
# Renamed: mdb145lx.pgm -> mdb145.pgm
# Renamed: mdb146rx.pgm -> mdb146.pgm
# Renamed: mdb147lx.pgm -> mdb147.pgm
# Renamed: mdb148rx.pgm -> mdb148.pgm
# Renamed: mdb149lx.pgm -> mdb149.pgm
# Renamed: mdb150rx.pgm -> mdb150.pgm
# Renamed: mdb151lx.pgm -> mdb151.pgm
# Renamed: mdb152rx.pgm -> mdb152.pgm
# Renamed: mdb153lx.pgm -> mdb153.pgm
# Renamed: mdb154rx.pgm -> mdb154.pgm
# Renamed: mdb155ll.pgm -> mdb155.pgm
# Renamed: mdb156rl.pgm -> mdb156.pgm
# Renamed: mdb157lm.pgm -> mdb157.pgm
# Renamed: mdb158rm.pgm -> mdb158.pgm
# Renamed: mdb159ll.pgm -> mdb159.pgm
# Renamed: mdb160rl.pgm -> mdb160.pgm
# Renamed: mdb161lm.pgm -> mdb161.pgm
# Renamed: mdb162rm.pgm -> mdb162.pgm
# Renamed: mdb163ll.pgm -> mdb163.pgm
# Renamed: mdb164rl.pgm -> mdb164.pgm
# Renamed: mdb165ls.pgm -> mdb165.pgm
# Renamed: mdb166rs.pgm -> mdb166.pgm
# Renamed: mdb167ll.pgm -> mdb167.pgm
# Renamed: mdb168rl.pgm -> mdb168.pgm
# Renamed: mdb169lm.pgm -> mdb169.pgm
# Renamed: mdb170rm.pgm -> mdb170.pgm
# Renamed: mdb171ll.pgm -> mdb171.pgm
# Renamed: mdb172rl.pgm -> mdb172.pgm
# Renamed: mdb173ll.pgm -> mdb173.pgm
# Renamed: mdb174rl.pgm -> mdb174.pgm
# Renamed: mdb175lm.pgm -> mdb175.pgm
# Renamed: mdb176rm.pgm -> mdb176.pgm
# Renamed: mdb177ls.pgm -> mdb177.pgm
# Renamed: mdb178rs.pgm -> mdb178.pgm
# Renamed: mdb179ls.pgm -> mdb179.pgm
# Renamed: mdb180rs.pgm -> mdb180.pgm
# Renamed: mdb181lm.pgm -> mdb181.pgm
# Renamed: mdb182rm.pgm -> mdb182.pgm
# Renamed: mdb183ll.pgm -> mdb183.pgm
# Renamed: mdb184rl.pgm -> mdb184.pgm
# Renamed: mdb185ls.pgm -> mdb185.pgm
# Renamed: mdb186rs.pgm -> mdb186.pgm
# Renamed: mdb187lm.pgm -> mdb187.pgm
# Renamed: mdb188rm.pgm -> mdb188.pgm
# Renamed: mdb189ll.pgm -> mdb189.pgm
# Renamed: mdb190rl.pgm -> mdb190.pgm
# Renamed: mdb191ls.pgm -> mdb191.pgm
# Renamed: mdb192rs.pgm -> mdb192.pgm
# Renamed: mdb193ll.pgm -> mdb193.pgm
# Renamed: mdb194rl.pgm -> mdb194.pgm
# Renamed: mdb195ll.pgm -> mdb195.pgm
# Renamed: mdb196rl.pgm -> mdb196.pgm
# Renamed: mdb197lm.pgm -> mdb197.pgm
# Renamed: mdb198rm.pgm -> mdb198.pgm
# Renamed: mdb199lm.pgm -> mdb199.pgm
# Renamed: mdb200rm.pgm -> mdb200.pgm
# Renamed: mdb201ll.pgm -> mdb201.pgm
# Renamed: mdb202rl.pgm -> mdb202.pgm
# Renamed: mdb203ll.pgm -> mdb203.pgm
# Renamed: mdb204rl.pgm -> mdb204.pgm
# Renamed: mdb205ll.pgm -> mdb205.pgm
# Renamed: mdb206rl.pgm -> mdb206.pgm
# Renamed: mdb207lm.pgm -> mdb207.pgm
# Renamed: mdb208rm.pgm -> mdb208.pgm
# Renamed: mdb209ll.pgm -> mdb209.pgm
# Renamed: mdb210rl.pgm -> mdb210.pgm
# Renamed: mdb211lm.pgm -> mdb211.pgm
# Renamed: mdb212rm.pgm -> mdb212.pgm
# Renamed: mdb213ls.pgm -> mdb213.pgm
# Renamed: mdb214rs.pgm -> mdb214.pgm
# Renamed: mdb215ll.pgm -> mdb215.pgm
# Renamed: mdb216rl.pgm -> mdb216.pgm
# Renamed: mdb217ll.pgm -> mdb217.pgm
# Renamed: mdb218rl.pgm -> mdb218.pgm
# Renamed: mdb219ll.pgm -> mdb219.pgm
# Renamed: mdb220rl.pgm -> mdb220.pgm
# Renamed: mdb221lm.pgm -> mdb221.pgm
# Renamed: mdb222rm.pgm -> mdb222.pgm
# Renamed: mdb223ls.pgm -> mdb223.pgm
# Renamed: mdb224rs.pgm -> mdb224.pgm
# Renamed: mdb225lm.pgm -> mdb225.pgm
# Renamed: mdb226rm.pgm -> mdb226.pgm
# Renamed: mdb227lm.pgm -> mdb227.pgm
# Renamed: mdb228rm.pgm -> mdb228.pgm
# Renamed: mdb229ll.pgm -> mdb229.pgm
# Renamed: mdb230rl.pgm -> mdb230.pgm
# Renamed: mdb231ll.pgm -> mdb231.pgm
# Renamed: mdb232rl.pgm -> mdb232.pgm
# Renamed: mdb233lm.pgm -> mdb233.pgm
# Renamed: mdb234rm.pgm -> mdb234.pgm
# Renamed: mdb235ll.pgm -> mdb235.pgm
# Renamed: mdb236rl.pgm -> mdb236.pgm
# Renamed: mdb237lm.pgm -> mdb237.pgm
# Renamed: mdb238rm.pgm -> mdb238.pgm
# Renamed: mdb239ll.pgm -> mdb239.pgm
# Renamed: mdb240rl.pgm -> mdb240.pgm
# Renamed: mdb241ls.pgm -> mdb241.pgm
# Renamed: mdb242rs.pgm -> mdb242.pgm
# Renamed: mdb243lm.pgm -> mdb243.pgm
# Renamed: mdb244rm.pgm -> mdb244.pgm
# Renamed: mdb245ls.pgm -> mdb245.pgm
# Renamed: mdb246rs.pgm -> mdb246.pgm
# Renamed: mdb247ll.pgm -> mdb247.pgm
# Renamed: mdb248rl.pgm -> mdb248.pgm
# Renamed: mdb249lm.pgm -> mdb249.pgm
# Renamed: mdb250rm.pgm -> mdb250.pgm
# Renamed: mdb251lm.pgm -> mdb251.pgm
# Renamed: mdb252rm.pgm -> mdb252.pgm
# Renamed: mdb253ll.pgm -> mdb253.pgm
# Renamed: mdb254rl.pgm -> mdb254.pgm
# Renamed: mdb255ll.pgm -> mdb255.pgm
# Renamed: mdb256rl.pgm -> mdb256.pgm
# Renamed: mdb257ll.pgm -> mdb257.pgm
# Renamed: mdb258rl.pgm -> mdb258.pgm
# Renamed: mdb259ll.pgm -> mdb259.pgm
# Renamed: mdb260rl.pgm -> mdb260.pgm
# Renamed: mdb261ls.pgm -> mdb261.pgm
# Renamed: mdb262rs.pgm -> mdb262.pgm
# Renamed: mdb263lm.pgm -> mdb263.pgm
# Renamed: mdb264rm.pgm -> mdb264.pgm
# Renamed: mdb265lm.pgm -> mdb265.pgm
# Renamed: mdb266rm.pgm -> mdb266.pgm
# Renamed: mdb267ll.pgm -> mdb267.pgm
# Renamed: mdb268rl.pgm -> mdb268.pgm
# Renamed: mdb269lm.pgm -> mdb269.pgm
# Renamed: mdb270rm.pgm -> mdb270.pgm
# Renamed: mdb271ll.pgm -> mdb271.pgm
# Renamed: mdb272rl.pgm -> mdb272.pgm
# Renamed: mdb273ll.pgm -> mdb273.pgm
# Renamed: mdb274rx.pgm -> mdb274.pgm
# Renamed: mdb275ll.pgm -> mdb275.pgm
# Renamed: mdb276rl.pgm -> mdb276.pgm
# Renamed: mdb277lm.pgm -> mdb277.pgm
# Renamed: mdb278rm.pgm -> mdb278.pgm
# Renamed: mdb279ll.pgm -> mdb279.pgm
# Renamed: mdb280rx.pgm -> mdb280.pgm
# Renamed: mdb281lm.pgm -> mdb281.pgm
# Renamed: mdb282rm.pgm -> mdb282.pgm
# Renamed: mdb283lm.pgm -> mdb283.pgm
# Renamed: mdb284rm.pgm -> mdb284.pgm
# Renamed: mdb285lm.pgm -> mdb285.pgm
# Renamed: mdb286rm.pgm -> mdb286.pgm
# Renamed: mdb287ls.pgm -> mdb287.pgm
# Renamed: mdb288rs.pgm -> mdb288.pgm
# Renamed: mdb289ls.pgm -> mdb289.pgm
# Renamed: mdb290rs.pgm -> mdb290.pgm
# Renamed: mdb291ll.pgm -> mdb291.pgm
# Renamed: mdb292rl.pgm -> mdb292.pgm
# Renamed: mdb293ll.pgm -> mdb293.pgm
# Renamed: mdb294rl.pgm -> mdb294.pgm
# Renamed: mdb295ll.pgm -> mdb295.pgm
# Renamed: mdb296rl.pgm -> mdb296.pgm
# Renamed: mdb297ll.pgm -> mdb297.pgm
# Renamed: mdb298rl.pgm -> mdb298.pgm
# Renamed: mdb299ll.pgm -> mdb299.pgm
# Renamed: mdb300rl.pgm -> mdb300.pgm
# Renamed: mdb301lm.pgm -> mdb301.pgm
# Renamed: mdb302rm.pgm -> mdb302.pgm
# Renamed: mdb303lm.pgm -> mdb303.pgm
# Renamed: mdb304rm.pgm -> mdb304.pgm
# Renamed: mdb305lm.pgm -> mdb305.pgm
# Renamed: mdb306rm.pgm -> mdb306.pgm
# Renamed: mdb307ll.pgm -> mdb307.pgm
# Renamed: mdb308rl.pgm -> mdb308.pgm
# Renamed: mdb309ll.pgm -> mdb309.pgm
# Renamed: mdb310rl.pgm -> mdb310.pgm
# Renamed: mdb311ll.pgm -> mdb311.pgm
# Renamed: mdb312rl.pgm -> mdb312.pgm
# Renamed: mdb313ll.pgm -> mdb313.pgm
# Renamed: mdb314rl.pgm -> mdb314.pgm
# Renamed: mdb315ll.pgm -> mdb315.pgm
# Renamed: mdb316rl.pgm -> mdb316.pgm
# Renamed: mdb317ls.pgm -> mdb317.pgm
# Renamed: mdb318rs.pgm -> mdb318.pgm
# Renamed: mdb319ll.pgm -> mdb319.pgm
# Renamed: mdb320rl.pgm -> mdb320.pgm
# Renamed: mdb321lm.pgm -> mdb321.pgm
# Renamed: mdb322rm.pgm -> mdb322.pgm
# All files renamed successfully.
